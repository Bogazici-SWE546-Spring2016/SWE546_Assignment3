# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import heapq as hp

# %%
df_iris = pd.read_csv(u'data/iris.txt',sep=' ')

# %%
sl = np.matrix(df_iris.sl[:]).T
sw = np.matrix(df_iris.sw[:]).T
pl = np.matrix(df_iris.pl[:]).T
pw = np.matrix(df_iris.pw[:]).T
A = np.hstack((sl,sw,pl,pw))
c = np.matrix(df_iris.c).T

# %%
class tup:
    def __init__(self, val, idx):
        self.val = val
        self.idx = idx
        
    def __lt__(self, other):        
        return self.val > other.val
    
    def __le__(self, other):
        return self.val <= other.val
 
    def __eq__(self, other):
        return self.val == other.val
    
    def __ne__(self, other):
        return self.val != other.val

    def __gt__(self, other):
        return self.val > other.val

    def __ge__(self, other):
        return self.val >= other.val

    def __str__(self):
        return '{:.3},{:d}'.format(self.val, self.idx)

# %%
def kNN(k, A, x, c):
    heap = []
    N = A.shape[0]   
    
    for i in range(k):
        hp.heappush(heap, tup(np.inf, -1))
    
    for i in range(N):
        e = A[i, :] - x
        e = e.reshape((4, 1))
        tp = tup(float(e.T * e), i)
        if tp <= heap[0]:
            hp.heapreplace(heap, tp)
            
    categories = []
    print '=============DISTANCE &  CATEGORY ============================'
    for t in range(len(heap)):
        h = hp.heappop(heap)
        categories.append(int(c[h.idx]))        
        print("DISTANCE = ",'{:.3}'.format(h.val),"TYPE: ",float(c[h.idx]))
    return max(set(categories), key=categories.count)

# %%
def predictionforCategories(k, A, c, testCategory):
    truePositive = 0
    trueNegative = 0
    falseNegative = 0
    falsePositive = 0
    
    for i in range(50 * (testCategory - 1), (50 + (50 * (testCategory - 1)))):
        predictedCategory = kNN(k, np.delete(A, i, axis=0), A[i,:], c)
            
        if predictedCategory == int(c[i]):
            if int(c[i]) == testCategory:
                truePositive += 1
            else:
                trueNegative += 1
        else:
            if int(c[i]) == testCategory:
                falseNegative += 1
            else:
                falsePositive += 1
    
    accuracy = (100. * (truePositive + trueNegative)) / (truePositive + trueNegative + falsePositive + falseNegative)
    precision = (100. * truePositive) / (truePositive + falsePositive)
    recall = (100. * truePositive) / (truePositive + falseNegative)
    
    print ("Accuracy %f, Precision %f, Recall %f" % (accuracy, precision, recall))

# %%
k = 3
test = A[1,:] + 3*np.random.randn(1,4)

print("\n")
print '=============TEST DATA ============================'
print test

result = kNN(k, A, test, c)
print("\n")
print '=============TEST DATA CATEGORY===================='
print(result)

print '===================================================================================================================='
print("\n")
print '=============TYPE 1 versus OTHERs=================='
predictionforCategories(k, A, c, 1)

print("\n")
print '=============TYPE 2 versus OTHERs=================='
predictionforCategories(k, A, c, 2)

print("\n")
print '=============TYPE 3 versus OTHERs=================='
predictionforCategories(k, A, c, 3)

print '===================================================================================================================='
# Out:
# =============TEST DATA ============================
# [[ 5.4178171   9.37416453  1.83813851 -1.39075186]]
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '30.2', 'TYPE: ', 1.0)
# ('DISTANCE = ', '29.5', 'TYPE: ', 1.0)
# ('DISTANCE = ', '28.1', 'TYPE: ', 1.0)
#
#
# =============TEST DATA CATEGORY====================
# 1
# ====================================================================================================================
#
#
# =============TYPE 1 versus OTHERs==================
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.01', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.07', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.11', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.09', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.01', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.0', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.0', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.09', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.08', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.01', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.08', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.12', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.3', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.22', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.17', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.38', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.3', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.15', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.01', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.22', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.15', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.11', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.06', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.08', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.06', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.27', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.26', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.21', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.14', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.17', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.14', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.04', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.09', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.08', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.14', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.15', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.0', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.0', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.11', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.0', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.0', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.06', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.01', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.59', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.51', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.39', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.09', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.17', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.14', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.06', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.06', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.06', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.01', 'TYPE: ', 1.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.05', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 1.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 1.0)
# Accuracy 100.000000, Precision 100.000000, Recall 100.000000
#
#
# =============TYPE 2 versus OTHERs==================
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.19', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.11', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.12', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.08', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.14', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.18', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.14', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.21', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.15', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.27', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.26', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.15', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.45', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.21', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.11', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.3', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.27', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.24', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.06', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.26', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.2', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.18', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.15', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.11', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.08', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.29', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.26', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.14', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.11', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.17', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.15', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.12', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.17', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.14', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.11', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.19', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.18', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.09', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.12', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.08', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.11', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.23', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.17', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.21', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.18', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.14', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.08', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.35', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.33', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.05', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.09', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.18', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.09', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.15', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.07', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.06', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.03', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.12', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.11', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.04', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.52', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.15', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.15', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.05', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 2.0)
# Accuracy 94.000000, Precision 100.000000, Recall 94.000000
#
#
# =============TYPE 3 versus OTHERs==================
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.26', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.25', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.18', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.0', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.17', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.16', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.15', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.11', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.3', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.28', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.63', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.58', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.54', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.28', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.19', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.38', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.36', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.31', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.5', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.45', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.4', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.18', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.14', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.14', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.14', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.11', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.26', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.26', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.24', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.14', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.14', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.74', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.67', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.17', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.8', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.3', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.17', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.29', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.27', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.19', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.09', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.11', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.37', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.17', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.14', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.19', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.15', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.08', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.08', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.11', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.01', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.27', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.26', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.22', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.21', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.86', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.78', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.17', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.18', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.01', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.14', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.11', 'TYPE: ', 2.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.34', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.31', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.29', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.44', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.3', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.29', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.18', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.15', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.15', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.08', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 2.0)
# ('DISTANCE = ', '0.02', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.03', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.12', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.22', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.07', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.0', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.1', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.15', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.14', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.13', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.12', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.05', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.31', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.09', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.06', 'TYPE: ', 3.0)
# =============DISTANCE &  CATEGORY ============================
# ('DISTANCE = ', '0.11', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.1', 'TYPE: ', 3.0)
# ('DISTANCE = ', '0.08', 'TYPE: ', 3.0)
# Accuracy 94.000000, Precision 100.000000, Recall 94.000000
# ====================================================================================================================
